# %% [markdown]
# # Analisi ultimi 6 mesi - analisi-dati-covid19-campania
# Dataset:
# [Link dataset - COVID-19 Monitoraggio situazione: Dati di dettaglio relativi alla Regione Campania](https://dati.regione.campania.it/catalogo/datasetdetail/covid-19-monitoraggio-situazione-dati-di-dettaglio-relativi-alla-regione-campania)
#
# **Grafici presenti**:
# - Andamento positivi
# - Andamento nuovi positivi giornalieri
# - Andamento % Positivi/Tamponi
# - Andamento tamponi giornalieri
# - Andamento ospedalizzati e terapia intensiva
# - Andamento % letalità

# %%
# Caricamento dati da notebook di pre-elaborazione dati
# %run pre_elaborazione_dati.ipynb
analisi_giorni = dati_selezionati.tail(180)

# %% [markdown]
# ## Andamento positivi

# %%
analisi_giorni.plot(kind='line', x='Data aggiornamento', y=["Totale positivi"], grid=True, title='Andamento positivi (ultimi 6 mesi)', figsize=(12,6))

# %% [markdown]
# ## Andamento nuovi positivi giornalieri

# %%
analisi_giorni.plot(kind='line', x='Data aggiornamento', y=["Nuovi positivi"], grid=True, title='Andamento nuovi positivi giornalieri (ultimi 6 mesi)', figsize=(12,6))

# %% [markdown]
# ## Andamento % Positivi/Tamponi

# %%
analisi_giorni.plot(kind='line', x='Data aggiornamento', y="% Positivi/Tamponi", grid=True, title='Andamento % Positivi/Tamponi (ultimi 6 mesi)', figsize=(12,6))

# %% [markdown]
# ## Andamento tamponi giornalieri

# %%
analisi_giorni.plot(kind='line', x='Data aggiornamento', y=["Tamponi giornalieri"], grid=True, title='Andamento tamponi giornalieri (ultimi 6 mesi)', figsize=(12,6))

# %% [markdown]
# ## Andamento ospedalizzati e terapia intensiva

# %%
analisi_giorni.plot(kind='line', x='Data aggiornamento', y=["Totale ospedalizzati", "Terapia Intensiva"], grid=True, title='Andamento ospedalizzati e terapia intensiva (ultimi 6 mesi)', figsize=(12,6))

# %% [markdown]
# ## Andamento % letalità

# %%
analisi_giorni.plot(kind='line', x='Data aggiornamento', y=["% Letalità"], grid=True, title='Andamento % letalità (ultimi 6 mesi)', figsize=(12,6))
